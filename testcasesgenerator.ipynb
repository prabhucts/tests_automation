# %%
# !pip install python-docx langchain gradio openai
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: langchain in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (0.3.21)
# Requirement already satisfied: gradio in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (5.22.0)
# Requirement already satisfied: openai in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (1.67.0)
# Collecting lxml>=3.1.0 (from python-docx)
#   Downloading lxml-5.3.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from python-docx) (4.12.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain) (0.3.47)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain) (0.3.18)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.115.11)
# Requirement already satisfied: ffmpy in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.29.3)
# Requirement already satisfied: jinja2<4.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydub in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.11.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.46.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.15.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio-client==1.8.0->gradio) (2024.12.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from gradio-client==1.8.0->gradio) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from openai) (0.9.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/llms/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
# Downloading lxml-5.3.1-cp311-cp311-macosx_10_9_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 3.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: lxml, python-docx
# Successfully installed lxml-5.3.1 python-docx-1.1.2

# %%
import os
from docx import Document
import gradio as gr
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from dotenv import load_dotenv

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv()
openai_api_key = os.getenv('OPENAI_API_KEY')
#anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
#google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
   
#if anthropic_api_key:
#    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
#else:
#   print("Anthropic API Key not set")

#if google_api_key:
#    print(f"Google API Key exists and begins {google_api_key[:8]}")
#else:
#    print("Google API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
def load_word_context(file_path):
    # Open and read the Word document
    doc = Document(file_path)
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return "\n".join(full_text)

# Set the path to your context document (#hardcoded line, needs to be changed)
context_file_path = "/Users/prabhu/Documents/GitHub/aiworkshop/knowledge-base/webapplication/Retail_web_application.docx"

# Load the application context from the Word document
application_context = load_word_context(context_file_path)

# Optionally, print the context to verify it's loaded correctly
print(application_context)
# Out:
# Table of Contents
# Functionality of the application
# Product Categories
# Technical Specifications
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Application web URL is Webazon.com.
#
# Browsing Products
# As a user, I want to browse a list of products so that I can see what is available.
# Acceptance Criteria:
# A landing or catalog page displays product thumbnails, names, and prices.
# Users can filter products by category or price range.
# Pagination or infinite scroll is provided if there are many products.
# Viewing Product Details
# As a user, I want to view detailed information about a product so that I can make informed purchasing decisions.
# Acceptance Criteria:
# Clicking a product leads to a detailed view.
# The product detail page includes images, full description, price, availability, and customer reviews.
# A clear “Add to Cart” button is available.
# 3. Adding Items to the Cart
# As a user, I want to add products to a shopping cart so that I can collect items I plan to purchase.
# Acceptance Criteria:
# An “Add to Cart” button updates the cart count.
# Visual confirmation (e.g., a toast notification) confirms the addition.
# The cart persists during the browsing session.
# 4. Managing the Shopping Cart
# As a user, I want to view and modify my shopping cart so that I can adjust quantities or remove items before purchase.
# Acceptance Criteria:
# A cart page displays all added items with product details, quantities, and prices.
# Users can update quantities or remove items.
# The total price is recalculated dynamically.
# 5. Checkout Process
# As a user, I want to go through a simple checkout process so that I can complete my purchase efficiently.
# Acceptance Criteria:
# A multi-step or single-page checkout that collects shipping and payment information.
# Order summary review before final confirmation.
# Confirmation page with order details and email confirmation sent upon successful purchase.
# 6. User Account Management (Optional)
# As a returning user, I want to create and manage my account so that I can save shipping and payment details for future purchases.
# Acceptance Criteria:
# Registration and login functionality.
# Secure profile page where users can view order history and update their information.
# Password recovery and secure session handling.
# 7. Administration (Optional)
# As an admin, I want to manage product listings so that I can add, update, or remove products from the catalog.
# Acceptance Criteria:
# An admin panel with CRUD (Create, Read, Update, Delete) operations for products.
# Secure login and role-based access control.
# Reporting features for tracking sales and inventory.
#
#
# Product Categories
# For this simple retail web page, consider highlighting a few distinctive categories to create a memorable user experience. For example:
# Sustainable Living: Eco-friendly home and lifestyle products that promote a greener lifestyle.
# Handcrafted Art: One-of-a-kind, artisan-made decor and accessories.
# Smart Tech: Innovative gadgets and smart home devices that simplify daily routines.
# Gourmet Bites: Curated selection of unique snacks and treats from local or artisanal producers.
#
# Updated Landing Page Specifications & Functionality
# 1. Landing Page Layout
# Hero Section:
# A visually appealing banner featuring the brand’s unique selling proposition.
# A call-to-action (CTA) prompting users to explore the products.
# Navigation & Menu:
# A top navigation bar with clear links for Home, Categories, Cart, and Account.
# A search bar to quickly locate products.
# Featured Unique Categories:
# Category Cards: Prominently display cards or tiles for the unique product categories mentioned above.
# Each card includes an image, a brief description, and a link to view all products in that category.
# Interactive Carousel: Optionally, a carousel feature can be used to showcase these categories dynamically.
# 2. Functionality for Unique Categories
# Dynamic Filtering:
# Allow users to filter products on the landing page by selecting one of the unique product categories.
# Update product listings instantly based on the selected category.
# Category Landing Pages:
# Each unique category (e.g., Sustainable Living, Handcrafted Art, Smart Tech, Gourmet Bites) links to its own subpage.
# These pages contain a detailed list of products with tailored descriptions, images, and reviews specific to that category.
# Visual Consistency:
# Use a consistent color scheme and typography for category cards, yet differentiate them with custom icons or imagery reflecting the category theme.
# Responsive Design:
# Ensure that the category cards and navigation are optimized for both mobile and desktop, maintaining an intuitive layout on all devices.
#
# Technical Specifications
# 1. Architecture
# Frontend:
# Built with HTML5, CSS3, and JavaScript.
# Optionally using a modern framework/library (e.g., React, Vue.js, or Angular) for dynamic components.
# Responsive design to support mobile and desktop views.
# Backend:
# Implemented using a server-side framework such as Node.js with Express, Python with Django/Flask, or Ruby on Rails.
# RESTful API endpoints for product listings, cart operations, user authentication, and checkout processes.
# Database:
# Relational (e.g., MySQL, PostgreSQL) or NoSQL (e.g., MongoDB) database to store product, user, and order data.
# Proper indexing and data validation to ensure performance and integrity.
# 2. Design & User Experience
# Responsive UI:
# Use CSS frameworks like Bootstrap or Tailwind CSS to ensure the design adapts to different screen sizes.
# Accessibility:
# Follow WCAG guidelines for accessible design, including keyboard navigation and screen reader support.
# Navigation:
# Clear menus, breadcrumbs, and search functionality for easy navigation through the site.
# 3. Security
# Data Protection:
# Use HTTPS to encrypt data in transit.
# Secure user authentication (e.g., JWT tokens or session-based authentication) and password hashing.
# Payment Integration:
# Integrate with secure payment gateways (e.g., Stripe, PayPal) that comply with PCI DSS standards.
# Input Validation:
# Server-side and client-side validation to prevent injection attacks and other vulnerabilities.
# 4. Performance & Scalability
# Asset Optimization:
# Optimize images and static assets.
# Leverage browser caching and Content Delivery Networks (CDNs) for faster content delivery.
# Scalability:
# Design the backend and database to handle increased load (e.g., load balancing, database replication).
# Modular code structure to facilitate the addition of new features over time.

# %%
from langchain.prompts import PromptTemplate

test_case_prompt = PromptTemplate(
    input_variables=["context", "user_query"],
    template="""Using the following application context:

{context}

Generate detailed test cases for the scenario:
{user_query}

Include edge cases, validation scenarios, and error handling."""
)

# %%
def generate_test_cases(user_query):
    # Use the extracted application context from the Word document
    return test_case_chain.run(context=application_context, user_query=user_query)

# %%
import os
from langchain_openai import OpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

# Ensure your API key is set in your environment
# For example, you might set it externally or like this:
# os.environ["OPENAI_API_KEY"] = "your-api-key-here"

# Initialize the LLM using the environment variable directly
llm = OpenAI(openai_api_key=os.environ["OPENAI_API_KEY"], temperature=0.7, max_tokens=500)

# Define the prompt template
test_case_prompt = PromptTemplate(
    input_variables=["context", "user_query"],
    template="""Using the following application context:

{context}

Generate detailed test cases for the scenario:
{user_query}

Include edge cases, validation scenarios, and error handling."""
)

# Create the chain
test_case_chain = LLMChain(llm=llm, prompt=test_case_prompt)

# Example function to generate test cases
def generate_test_cases(user_query, context):
    return test_case_chain.run(context=context, user_query=user_query)

# Example usage (ensure you have loaded your application_context)
sample_query = "Generate test cases for the product categories functionality of the retail web application."
print(generate_test_cases(sample_query, application_context))
# Out:
# 1. Test Case: Verify that the landing page displays all unique product categories.
#
# Steps:
# 1. Navigate to the landing page of the web application.
# 2. Verify that all unique product categories (Sustainable Living, Handcrafted Art, Smart Tech, Gourmet Bites) are displayed as category cards or tiles.
# 3. Click on each category card and verify that it links to the respective subpage.
# 4. Repeat the same steps on different browsers and devices to ensure consistent display.
#
# Expected Result: All unique product categories are displayed correctly on the landing page.
#
# 2. Test Case: Verify that the category cards are visually consistent with a differentiated design for each category.
#
# Steps:
# 1. Navigate to the landing page of the web application.
# 2. Verify that each category card has a different design or imagery that reflects the theme of the category.
# 3. Check the color scheme and typography to ensure consistency across all category cards.
# 4. Repeat the same steps on different browsers and devices to ensure consistent display.
#
# Expected Result: Each category card has a visually differentiated design that reflects the theme of the category, with consistent color scheme and typography.
#
# 3. Test Case: Verify that the category cards are responsive and optimized for different screen sizes.
#
# Steps:
# 1. Navigate to the landing page of the web application.
# 2. Resize the browser window to different screen sizes (e.g., desktop, tablet, mobile).
# 3. Verify that the category cards adapt to the screen size and maintain an intuitive layout.
# 4. Repeat the same steps on different browsers and devices to ensure consistent display.
#
# Expected Result: The category cards are responsive and adapt to different screen sizes, maintaining an intuitive layout.
#
# 4. Test Case: Verify that the dynamic filtering feature works correctly for product listings.
#
# Steps:
# 1. Navigate to the landing page of the web application.
# 2. Select one of the unique product categories (e.g., Sustainable Living) from the top navigation menu.
# 3. Verify that the product listings are updated instantly to display only products from the selected category.
# 4. Repeat the same steps for other categories to ensure the dynamic filtering feature works correctly.
# 5. Try to select a category that does not have any products and verify that an appropriate message is displayed.
#
# Expected Result: The product listings are updated correctly based on the selected category, and an appropriate message is displayed if no products are available.
#
# 5. Test Case: Verify that the category subpages display a detailed list of products with tailored descriptions, images, and reviews specific to

# %%
iface = gr.Interface(
    fn=generate_test_cases, 
    inputs="text", 
    outputs="text",
    title="Test Cases Generator",
    description="Generate test cases for the web application using the provided context."
)

iface.launch()
# Out:
# /opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/utils.py:1024: UserWarning: Expected 2 arguments for function <function generate_test_cases at 0x15fbf9d00>, received 1.
#   warnings.warn(
# /opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/utils.py:1028: UserWarning: Expected at least 2 arguments for function <function generate_test_cases at 0x15fbf9d00>, received 1.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/helpers.py:968: UserWarning: Unexpected argument. Filling with None.
#   warnings.warn("Unexpected argument. Filling with None.")
